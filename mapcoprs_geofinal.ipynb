# %% [markdown]
# ### MapCorps , NYC "power wall" menthol rating

# %% [markdown]
# #### Author : Avigai Vantu NYU mHealth , March 2017

# %%
import pandas as pd
import numpy as np
#import geopandas as gpd

from sklearn.metrics import cohen_kappa_score

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# we need to account for diffrences b/w raters, so find the interval between two columns
#for example and flag anyt gap which is bigger than 20%.

# %%
mc = pd.read_csv('geofinal.csv')

# %%
mc.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  outletID    Subway Station  \
# 0           0             0               0       1.0    7th Ave. (B,Q)
# 1           1             1               1       2.0    7th Ave. (B,Q)
# 2           2             2               2       3.0    7th Ave. (B,Q)
# 3           3             3               3       4.0  Bedford Ave. (L)
# 4           4             4               4       5.0  Bedford Ave. (L)
#
#                Tobacco Outlet Address      ZIP  \
# 0  310 FLATBUSH AVE Brooklyn NY 11238  11238.0
# 1  387 FLATBUSH AVE Brooklyn NY 11238  11238.0
# 2  322 FLATBUSH AVE Brooklyn NY 11238  11238.0
# 3      150 N 7TH ST Brooklyn NY 11211  11221.0
# 4   183 BEDFORD AVE Brooklyn NY 11211  11221.0
#
#                              Important Notes Images (Y/N) Quality (Y/N)  \
# 0            partially hidden behind counter            Y             Y
# 1  very far behind counter, difficult to see            Y            Y
# 2                Difficult to see if menthol           Y             Y
# 3                                        NaN            Y             Y
# 4                                        NaN            Y             Y
#
#      ...     gm_pkgclr_y other_y other_quantity_y other_flavor_y  \
# 0    ...             NaN       N              NaN            NaN
# 1    ...             NaN       N              NaN            NaN
# 2    ...             NaN       N              NaN            NaN
# 3    ...             NaN       N              NaN            NaN
# 4    ...             NaN       N              NaN            NaN
#
#   other_pkgclr_y  unidentifiable_brand_y  issues_y  \
# 0            NaN                       1       NaN
# 1            NaN                     NaN       NaN
# 2            NaN                     NaN       NaN
# 3            NaN                     NaN       NaN
# 4            NaN                     NaN       NaN
#
#                               geo22        lon        lat
# 0  [40.6773151, -73.97286009999999] -73.972860  40.677315
# 1         [40.6760809, -73.9714004] -73.971400  40.676081
# 2         [40.6770555, -73.9726146] -73.972615  40.677056
# 3           [40.718636, -73.959009] -73.959009  40.718636
# 4  [40.7177917, -73.95749649999999] -73.957496  40.717792
#
# [5 rows x 132 columns]

# %%
print  mc.dtypes
# Out:
# Unnamed: 0                   int64
# Unnamed: 0.1                 int64
# Unnamed: 0.1.1               int64
# outletID                   float64
# Subway Station              object
# Tobacco Outlet Address      object
# ZIP                        float64
# Important Notes             object
# Images (Y/N)                object
# Quality (Y/N)               object
# Quality (Y/N) Comments      object
# Name                        object
# Borough                     object
# name_1                      object
# Cons 1                      object
# numerator green_1          float64
# denom_all_1                float64
# Non-cons 1                  object
# numerator all_1            float64
# denom_all_1.1              float64
# name_2                      object
# Cons 2                      object
# numerator green_2          float64
# denom_all_2                float64
# Non-cons 2                  object
# Num_All_2                  float64
# denom_all_2.1               object
# Name*                       object
# Cons*                       object
# Num_Green                  float64
#                             ...
# zz_pkgclr_y                 object
# show_y                      object
# sh_quantity_y              float64
# sh_flavor_y                 object
# sh_pkgclr_y                 object
# swisher sweets_y            object
# ss_quantity_y              float64
# ss_flavor_y                 object
# ss_pkgclr_y                float64
# hype_y                      object
# hy_quantity_y              float64
# hy_flavor_y                 object
# hy_pkgclr_y                 object
# d'ville_y                   object
# dv_quantity_y              float64
# dv_flavor_y                 object
# dv_pkgclr_y                 object
# game_y                      object
# gm_quantity_y              float64
# gm_flavor_y                 object
# gm_pkgclr_y                 object
# other_y                     object
# other_quantity_y           float64
# other_flavor_y              object
# other_pkgclr_y              object
# unidentifiable_brand_y      object
# issues_y                   float64
# geo22                       object
# lon                        float64
# lat                        float64
# Length: 132, dtype: object

# %%
#mc= mc.reset_index()
#del mc['index']

# %%
#mc = mc.reset_index(drop=True)

mc.reset_index(inplace=True)

# %%
# making sure .1 and .2 are duplicats 

print mc['denom_all_1.1'].head()
print mc['denom_all_1'].head()
print mc['denom_all_2.1'].head()
print mc['denom_all_2'].head()
print mc['Denom_All.1'].head()
# Out:
# 0     38.0
# 1     14.0
# 2    339.0
# 3     34.0
# 4     46.0
# Name: denom_all_1.1, dtype: float64
# 0     38.0
# 1     14.0
# 2    339.0
# 3     34.0
# 4     46.0
# Name: denom_all_1, dtype: float64
# 0    34
# 1    18
# 2    42
# 3    34
# 4    50
# Name: denom_all_2.1, dtype: object
# 0    34.0
# 1    18.0
# 2    42.0
# 3    34.0
# 4    50.0
# Name: denom_all_2, dtype: float64
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Denom_All.1, dtype: float64

# %%
# delete duplicates 

del mc['denom_all_1.1']

del mc['denom_all_2.1']

del mc['Denom_All.1']

# %%
#how does it looks now? 

print  mc.dtypes
# Out:
# index                        int64
# Unnamed: 0                   int64
# Unnamed: 0.1                 int64
# Unnamed: 0.1.1               int64
# outletID                   float64
# Subway Station              object
# Tobacco Outlet Address      object
# ZIP                        float64
# Important Notes             object
# Images (Y/N)                object
# Quality (Y/N)               object
# Quality (Y/N) Comments      object
# Name                        object
# Borough                     object
# name_1                      object
# Cons 1                      object
# numerator green_1          float64
# denom_all_1                float64
# Non-cons 1                  object
# numerator all_1            float64
# name_2                      object
# Cons 2                      object
# numerator green_2          float64
# denom_all_2                float64
# Non-cons 2                  object
# Num_All_2                  float64
# Name*                       object
# Cons*                       object
# Num_Green                  float64
# Denom_All                  float64
#                             ...
# zz_pkgclr_y                 object
# show_y                      object
# sh_quantity_y              float64
# sh_flavor_y                 object
# sh_pkgclr_y                 object
# swisher sweets_y            object
# ss_quantity_y              float64
# ss_flavor_y                 object
# ss_pkgclr_y                float64
# hype_y                      object
# hy_quantity_y              float64
# hy_flavor_y                 object
# hy_pkgclr_y                 object
# d'ville_y                   object
# dv_quantity_y              float64
# dv_flavor_y                 object
# dv_pkgclr_y                 object
# game_y                      object
# gm_quantity_y              float64
# gm_flavor_y                 object
# gm_pkgclr_y                 object
# other_y                     object
# other_quantity_y           float64
# other_flavor_y              object
# other_pkgclr_y              object
# unidentifiable_brand_y      object
# issues_y                   float64
# geo22                       object
# lon                        float64
# lat                        float64
# Length: 130, dtype: object

# %%
# create new columns to caclulate the prcentage of green products in the 
#"power wall" by dviding numerator green by denominator green


#for green 1

mc['precgreen1'] = (mc['numerator green_1']/mc['denom_all_1'])*100

#for green 2

mc['precgreen2'] = (mc['numerator green_2']/mc['denom_all_2'])*100

#for non green menthol products 1

mc['precall1'] = (mc['numerator all_1']/mc['denom_all_1'])*100

#for non green menthol products 2

mc['precall2'] = (mc['Num_All_2']/mc['denom_all_2'])*100

# %%
#mc['Num_All_2']['precall2'][71:74]

# %%
#averge between rater one and rater two. 

# for green apply: create new column for:  (precntage of green 1 + precentage of green 2)/ 2 

mc['avrgreen'] = (mc['precgreen1'] + mc['precgreen2']) / 2


# for green + non green menthol products apply: (precntage of all 1 + precentage of all 2)/ 2 

mc['avrall'] = (mc['precall1'] + mc['precall2']) / 2

# %%
#does the avr look reasonable for green rating? 

#new
print mc['avrgreen'].head()
#and the rest
print mc['precgreen1'].head()
print mc['precgreen2'].head()
# Out:
# 0    10.835913
# 1    19.047619
# 2    15.992415
# 3    26.470588
# 4    30.217391
# Name: avrgreen, dtype: float64
# 0    15.789474
# 1    21.428571
# 2    17.699115
# 3    26.470588
# 4    30.434783
# Name: precgreen1, dtype: float64
# 0     5.882353
# 1    16.666667
# 2    14.285714
# 3    26.470588
# 4    30.000000
# Name: precgreen2, dtype: float64

# %%
# how about for non green products? 

#new
print mc['avrall'].head()

#an the rest
print mc['precall1'].head()
print mc['precall2'].head()

# when there's an NaN in one column or both the avr will be NaN as well
# Out:
# 0    13.777090
# 1    22.619048
# 2    20.754319
# 3    30.882353
# 4    36.304348
# Name: avrall, dtype: float64
# 0    15.789474
# 1    28.571429
# 2    17.699115
# 3    29.411765
# 4    32.608696
# Name: precall1, dtype: float64
# 0    11.764706
# 1    16.666667
# 2    23.809524
# 3    32.352941
# 4    40.000000
# Name: precall2, dtype: float64

# %%
# let's try to identify outliers or gaps among raters. 
# to do so I will calculate the absulute interval b/w the 
# precentage of green products of rater 1 and rater 2 

# create a new column ==  | %green1 - %green2 |

mc['green_gap'] = abs(mc['precgreen1'] - mc['precgreen2'])

# create a new column ==  | %green1 - %green2 | 

mc['all_gap'] = abs(mc['precall1'] - mc['precall2'])


print mc.green_gap.head()

print mc.all_gap.head()
# Out:
# 0    9.907121
# 1    4.761905
# 2    3.413401
# 3    0.000000
# 4    0.434783
# Name: green_gap, dtype: float64
# 0     4.024768
# 1    11.904762
# 2     6.110409
# 3     2.941176
# 4     7.391304
# Name: all_gap, dtype: float64

# %%
#plot the gap b/w rater one and rater 2


mc.green_gap.plot()

mc.all_gap.plot()

print "green mean", mc.green_gap.mean()

print "all mean", mc.all_gap.mean()
# Out:
# green mean 11.0073869843
# all mean 14.0829666993

# %%
# calculate standard deviation 

# 1. for all
print "std of precentage of all", mc.avrall.std()

# 2. for green 

print "std of precentage of green", mc.avrgreen.std()
# Out:
# std of precentage of all 16.3190442099
# std of precentage of green 15.2750136793

# %%
# plot the

# %%
# create data frames which have more than 20% gap b/w raters

mc_green_gap = mc[mc['green_gap']>20]
mc_all_gap = mc[mc['all_gap']>20]

#who is this outlier? 
print mc[mc['green_gap']>50].head()
# Out:
#      index  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  outletID  \
# 66      66          66            66              66      67.0
# 76      76          76            76              76      77.0
# 83      83          83            83              83      84.0
# 123    123         123           123             123     124.0
#
#                            Subway Station  \
# 66                St Lawrence Av, 6 train
# 76   Westchester Sq - E Tremont, 6 train
# 83                        125 St, 1 train
# 123                     67th Ave. (E,M,R)
#
#                     Tobacco Outlet Address      ZIP  \
# 66         1791 GLEASON AVE Bronx NY 10472  10472.0
# 76   134 WESTCHESTER SQUARE Bronx NY 10461  10461.0
# 83       501 W 125TH ST Manhattan NY 10027  10027.0
# 123         6725 AUSTIN ST Queens NY 11375  11375.0
#
#                 Important Notes Images (Y/N)    ...            lon        lat  \
# 66                          NaN            Y    ...     -73.866601  40.829955
# 76                 Vendor empty            Y    ...     -73.842024  40.840644
# 83                          NaN            Y    ...     -73.956391  40.813788
# 123  partially blocked by signs            Y    ...     -73.854586  40.723971
#
#     precgreen1 precgreen2   precall1   precall2   avrgreen     avrall  \
# 66   16.666667  67.500000  16.666667  70.000000  42.083333  43.333333
# 76    0.000000  66.666667   0.000000  66.666667  33.333333  33.333333
# 83   22.500000  75.000000  22.500000  83.333333  48.750000  52.916667
# 123  66.666667  15.384615  66.666667  21.153846  41.025641  43.910256
#
#      green_gap    all_gap
# 66   50.833333  53.333333
# 76   66.666667  66.666667
# 83   52.500000  60.833333
# 123  51.282051  45.512821
#
# [4 rows x 138 columns]

# %%
mc_green_gap.head()
# Out:
#     index  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  outletID  \
# 10     10          10            10              10      11.0
# 19     19          19            19              19      20.0
# 29     29          29            29              29      30.0
# 30     30          30            30              30      31.0
# 37     37          37            37              37      38.0
#
#                  Subway Station                  Tobacco Outlet Address  \
# 10          Kings Highway (B,Q)        1521 KINGS HWY Brooklyn NY 11229
# 19           Kosciuszko St. (J)         1165 BROADWAY Brooklyn NY 11221
# 29  Pennsylvania Ave. (2,3,4,5)       578 LIVONIA AVE Brooklyn NY 11207
# 30  Pennsylvania Ave. (2,3,4,5)  504 PENNSYLVANIA AVE Brooklyn NY 11207
# 37           Sterling St. (2,5)     1037 NOSTRAND AVE Brooklyn NY 11225
#
#         ZIP Important Notes Images (Y/N)    ...            lon        lat  \
# 10  11229.0        Pharmacy            Y    ...     -73.957611  40.609334
# 19  11221.0             NaN            Y    ...     -73.927762  40.693226
# 29  11207.0             NaN            Y    ...     -73.895771  40.664306
# 30  11207.0             NaN            Y    ...     -73.894405  40.664971
# 37  11225.0             NaN            Y    ...     -73.950675  40.662920
#
#    precgreen1 precgreen2   precall1   precall2   avrgreen     avrall  \
# 10  12.307692  45.161290  16.923077  12.903226  28.734491  14.913151
# 19  17.307692  46.153846  17.307692  46.153846  31.730769  31.730769
# 29  28.571429  50.000000  28.571429  66.666667  39.285714  47.619048
# 30  11.111111  42.105263  11.111111  57.894737  26.608187  34.502924
# 37   7.692308  30.769231   7.692308  30.769231  19.230769  19.230769
#
#     green_gap    all_gap
# 10  32.853598   4.019851
# 19  28.846154  28.846154
# 29  21.428571  38.095238
# 30  30.994152  46.783626
# 37  23.076923  23.076923
#
# [5 rows x 138 columns]

# %%
#change columns name

mc_all_gap['Subway_Station'] = mc_all_gap['Subway Station']
mc_all_gap['Tobacco_Outlet_Addres'] = mc_all_gap['Tobacco Outlet Address']
mc_green_gap['Subway_Station'] = mc_green_gap['Subway Station']
mc_green_gap['Tobacco_Outlet_Addres'] = mc_green_gap['Tobacco Outlet Address']
# Out:
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(mc_all_gap)
# Out:
# 34

# %%
len(mc_green_gap)
# Out:
# 30

# %%
all_gap = mc_all_gap[['outletID','Subway_Station','Tobacco_Outlet_Addres']].copy()
green_gap = mc_green_gap[['outletID','Subway_Station','Tobacco_Outlet_Addres']].copy()

# %%
print len(green_gap)
print len(all_gap)
# Out:
# 30
# 34

# %%
#export to csv
all_gap.to_csv('mc_all_gap.csv')
green_gap.to_csv('mc_green_gap.csv')

# %%
#create data frames for each borough 

# 1. Queens: 

qndf = mc[mc['Borough'] =='QN']

# 2. Brooklyn: 

bkdf = mc[mc['Borough']== 'BK']

# 3. Bronx 

bxdf = mc[mc['Borough']== 'BX']

# 4. Manahttan 

mndf = mc[mc['Borough']== 'MN']

# %%
# print number of outlets per borough

print 'bronx', len(bxdf)

print 'brooklyn', len(bkdf)

print 'queens' , len(qndf)

print 'manahattan', len(mndf)
# Out:
# bronx 39
# brooklyn 39
# queens 46
# manahattan 38

# %%
# reset 4 df index 

mndf.reset_index(inplace=True)
qndf.reset_index(inplace=True)
bxdf.reset_index(inplace=True)
bkdf.reset_index(inplace=True)

# %%
# plot the precentage green and non green for each boroough 

#bronx

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Bronx')

bxdf.avrall.plot()

bxdf.avrgreen.plot()
plt.show()

#brooklyn

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Brooklyn')

bkdf.avrall.plot()

bkdf.avrgreen.plot()
plt.show()

#Manahattan 

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Manahattan')

mndf.avrall.plot()

mndf.avrgreen.plot()
plt.show()


#Queens

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Queens')

qndf.avrall.plot()

qndf.avrgreen.plot()
plt.show()

# %%
del mndf['index']

# %%
bkdf
# Out:
#     level_0  index  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1
# 23             Norwood & Fulton        3185 FULTON ST Brooklyn NY 11208
# 24             Norwood & Fulton        3139 FULTON ST Brooklyn NY 11208
# 25             Norwood & Fulton        3142 FULTON ST Brooklyn NY 11208
# 26             Norwood & Fulton        3118 FULTON ST Brooklyn NY 11208
# 27  Pennsylvania Ave. (2,3,4,5)        734 DUMONT AVE Brooklyn NY 11207
# 28  Pennsylvania Ave. (2,3,4,5)     575 RIVERDALE AVE Brooklyn NY 11207
# 29  Pennsylvania Ave. (2,3,4,5)       578 LIVONIA AVE Brooklyn NY 11207
# 30  Pennsylvania Ave. (2,3,4,5)  504 PENNSYLVANIA AVE Brooklyn NY 11207
# 31  Pennsylvania Ave. (2,3,4,5)  509 PENNSYLVANIA AVE Brooklyn NY 11207
# 32           Sterling St. (2,5)      413 LEFFERTS AVE Brooklyn NY 11225
# 33           Sterling St. (2,5)       250 EMPIRE BLVD Brooklyn NY 11225
# 34           Sterling St. (2,5)     1079 NOSTRAND AVE Brooklyn NY 11225
# 35           Sterling St. (2,5)     1080 NOSTRAND AVE Brooklyn NY 11225
# 36           Sterling St. (2,5)     1040 NOSTRAND AVE Brooklyn NY 11225
# 37           Sterling St. (2,5)     1037 NOSTRAND AVE Brooklyn NY 11225
# 38           Sterling St. (2,5)        410 ROGERS AVE Brooklyn NY 11225
#
#         ZIP                                  Important Notes    ...      \
# 0   11238.0                  partially hidden behind counter    ...
# 1   11238.0        very far behind counter, difficult to see    ...
# 2   11238.0                      Difficult to see if menthol    ...
# 3   11221.0                                              NaN    ...
# 4   11221.0                                              NaN    ...
# 5   11221.0                      paritally blocked by vendor    ...
# 6   11249.0                                              NaN    ...
# 7   11249.0                            display is misleading    ...
# 8   11221.0                          Best wall of cigs seen     ...
# 9   11229.0                                blocked by vendor    ...
# 10  11229.0                                         Pharmacy    ...
# 11  11229.0                                              NaN    ...
# 12  11229.0                                              NaN    ...
# 13  11229.0                                              NaN    ...
# 14  11229.0  Don't have clear photos of full counter display    ...
# 15  11229.0                                              NaN    ...
# 16  11229.0                                              NaN    ...
# 17  11223.0                                              NaN    ...
# 18  11229.0                                         Pharmacy    ...
# 19  11221.0                                              NaN    ...
# 20  11221.0                                              NaN    ...
# 21  11221.0                                              NaN    ...
# 22  11221.0                                              NaN    ...
# 23  11208.0                                      1/3 menthol    ...
# 24  11208.0                                              NaN    ...
# 25  11208.0                                              NaN    ...
# 26  11208.0                                              NaN    ...
# 27  11207.0                                              NaN    ...
# 28  11207.0                             Not clearly visible     ...
# 29  11207.0                                              NaN    ...
# 30  11207.0                                              NaN    ...
# 31  11207.0            Folder on drive labeled "Probably(?)"    ...
# 32  11225.0                                              NaN    ...
# 33  11225.0                                              NaN    ...
# 34  11225.0                                        no prices    ...
# 35  11225.0                                        no prices    ...
# 36  11225.0                                              NaN    ...
# 37  11225.0                                              NaN    ...
# 38  11225.0                   cigs are hidden behind counter    ...
#
#           lon        lat precgreen1  precgreen2    precall1    precall2  \
# 33         300 W BROADWAY Manhattan NY 10007  10007.0
#
#                                    Important Notes Images (Y/N)    ...      \
# 12  photos maybe be switched with the outlet below            Y    ...
# 14                                             NaN            Y    ...
# 18                                      bad images            Y    ...
# 29                                             NaN            Y    ...
# 30                                             NaN            Y    ...
# 31                                     Duane Reade            Y    ...
# 32                                     Duane Reade            Y    ...
# 33                                             NaN            Y    ...
#
#           lon        lat precgreen1 precgreen2   precall1   precall2  \
# 12 -73.971984  40.793462   9.411765  21.739130  12.941176  26.482213
# 14 -74.010959  40.709605  13.888889  10.000000  19.444444  13.333333
# 18 -74.009126  40.709497  16.666667  16.666667  16.666667  16.666667
# 29 -73.985367  40.732871  11.111111  21.481481  13.450292  22.962963
# 30 -73.989990  40.735334  18.716578  13.768116  10.160428  18.840580
# 31 -73.990257  40.734279  13.125000  14.035088  16.562500  17.894737
# 32 -73.989595  40.733988  10.559006   8.992806  16.149068  14.388489
# 33 -74.004597  40.721732  10.526316  11.200000  10.526316  20.000000
#
#      avrgreen     avrall  green_gap    all_gap
# 12  15.575448  19.711695  12.327366  13.541037
# 14  11.944444  16.388889   3.888889   6.111111
# 18  16.666667  16.666667   0.000000   0.000000
# 29  16.296296  18.206628  10.370370   9.512671
# 30  16.242347  14.500504   4.948462   8.680152
# 31  13.580044  17.228618   0.910088   1.332237
# 32   9.775906  15.268779   1.566200   1.760579
# 33  10.863158  15.263158   0.673684   9.473684
#
# [8 rows x 138 columns]

# %%
#calculate average for each borough - data frame for both green and all, one value

# Bronx 

print '- Bronx average all is',  bxdf.avrall.mean()
print '- Bronx average green is',  bxdf.avrgreen.mean()

# Brooklyn 

print '- Brooklyn average all is',  bkdf.avrall.mean()
print '- Brooklyn average green is',  bkdf.avrgreen.mean()

# Queens 

print '- Queens average all is',  qndf.avrall.mean()
print '- Queens average green is',  qndf.avrgreen.mean()

# Manahattan 

print '- Manahattan average all is',  mndf.avrall.mean()
print '- Manahattan average green is',  mndf.avrgreen.mean()
# Out:
# - Bronx average all is 40.152260707
# - Bronx average green is 34.7458677395
# - Brooklyn average all is 33.6718250267
# - Brooklyn average green is 29.4244644577
# - Queens average all is 37.9173209297
# - Queens average green is 29.6516337811
# - Manahattan average all is 33.3306638771
# - Manahattan average green is 26.4493733592

# %%
#average of green products per

# %%
print mc['precgreen2'].head()
print mc['precall2'].head()
# Out:
# 0     5.882353
# 1    16.666667
# 2    14.285714
# 3    26.470588
# 4    30.000000
# Name: precgreen2, dtype: float64
# 0    11.764706
# 1    16.666667
# 2    23.809524
# 3    32.352941
# 4    40.000000
# Name: precall2, dtype: float64

# %%
#green1 =mc['numeratorgreen1'].tolist()
#green2 =mc['numeratorgreen2'].tolist()

# %% [markdown]
# ## cohen's kappa test:

# %%
#testing cohen's kappa with fabricated lists as inputs
green1 = [2,3,4,5,5,5,5,5,4,3,3,2,2]
green2 = [2,3,4,5,5,5,5,5,4,4,3,2,2]
mc['numeratorgreen1'] = mc['numerator green_1']
mc['numeratorgreen2'] = mc['numerator green_2']

# %%
cohen_kappa_score(precgreen1, precgreen2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-17f136678d6e> in <module>()
# ----> 1 cohen_kappa_score(precgreen1, precgreen2)
#
# NameError: name 'precgreen1' is not defined

# %%
len(mc)

# %%
print mc.columns

# %%
print mc['Borough'].value_counts()

# %%
print mc['Subway Station'].value_counts()

# %%
#print mc['ZIP'].value_counts()

# %% [markdown]
# ### Calculate precentage of green products per rater #1

# %%
#mc['rater_1_green_prec'] = mc['numerator green_1']/ mc['denominator green_1']

# %%
#print mc['rater_1_green_prec'].head(10)

# %% [markdown]
# ### Calculate precentage of all menthol products per rater #1

# %%
 mc['rater_1_all_prec']= mc['numerator all_1']/ mc['denominator all_1']

# %%
print mc['rater_1_all_prec'].head(10)

# %% [markdown]
# ### Calculate precentage of green products per rater #2

# %%
mc['rater_2_green_prec'] = mc['numerator green_2']/ mc['denominator green_2']

# %%
print mc['rater_2_green_prec'].head(10)

# %% [markdown]
# ## DataFrame to CSV

# %%
mc.to_csv('mapcorps analysis')

# %%
 mc[mc['Borough']=='BK' & mc['Images (Y/N)']=='Y', 'yes', 'no')]

# %% [markdown]
# ## by borough have images at all

# %%
print "Brooklyn Images", len(mc[(mc['Borough'] == "BK") & (mc['Images (Y/N)'] == "Y")]) 
print "Queens Imgeas", len(mc[(mc['Borough'] == "QN") & (mc['Images (Y/N)'] == "Y")]) 
print "Bronx Images", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y")]) 
print "Manhattan Images", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y")])

# %% [markdown]
# ## by borough have images with good quality

# %%
#print "Brooklyn", len(mc[(mc['Borough'] == "BK") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 
print "Brooklyn quality", len(mc[(mc['Borough'] == "BK")  & (mc['Images (Y/N)'] == "Y")& (mc['Quality (Y/N)'] == "Y")]) 
print "Queens quality", len(mc[(mc['Borough'] == "QN")  & (mc['Images (Y/N)'] == "Y")& (mc['Quality (Y/N)'] == "Y")]) 
print "Bronx quality", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 
print "Manhattan quality", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 



#print "Queens", len(mc[(mc['Borough'] == "QN") & (mc['Images (Y/N)'] == "Y")]) 
#print "Bronx", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y")]) 
#print "Manhattan", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y")])

# %%
print mc.columns

# %%
mc.Borough.unique()

# %%
mc['SubwaySatation'] = mc['Subway Station']

# %%
mc.SubwaySatation.unique()

# %%
mc.ZIP.unique()

# %%
mc.Name.unique()
