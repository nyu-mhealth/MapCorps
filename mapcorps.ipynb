# %% [markdown]
# ### MapCorps , NYC "power wall" menthol rating

# %% [markdown]
# #### Author : Avigai Vantu NYU mHealth , March 2017

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

from sklearn.metrics import cohen_kappa_score

# %pylab inline
# Out:
# Failed `CDLL(/opt/local/lib/libgeos_c.dylib)`
# Populating the interactive namespace from numpy and matplotlib

# %%
# we need to account for diffrences b/w raters, so find the interval between two columns
#for example and flag anyt gap which is bigger than 20%.

# %%
mc = pd.read_csv('mapcorps_stopsMar22.csv')

# %%
mc.head(5)
# Out:
#    outletID    Subway Station              Tobacco Outlet Address    ZIP  \
# 0         1    7th Ave. (B,Q)  310 FLATBUSH AVE Brooklyn NY 11238  11238
# 1         2    7th Ave. (B,Q)  387 FLATBUSH AVE Brooklyn NY 11238  11238
# 2         3    7th Ave. (B,Q)  322 FLATBUSH AVE Brooklyn NY 11238  11238
# 3         4  Bedford Ave. (L)      150 N 7TH ST Brooklyn NY 11211  11221
# 4         5  Bedford Ave. (L)   183 BEDFORD AVE Brooklyn NY 11211  11221
#
#                              Important Notes Images (Y/N) Quality (Y/N)  \
# 0            partially hidden behind counter            Y             Y
# 1  very far behind counter, difficult to see            Y            Y
# 2                Difficult to see if menthol           Y             Y
# 3                                        NaN            Y             Y
# 4                                        NaN            Y             Y
#
#                         Quality (Y/N) Comments              Name Borough  \
# 0                                             Y          Janelle      BK
# 1  Y - But does not capture all cigs on display          Janelle      BK
# 2                                   Y - Blurry           Janelle      BK
# 3                                             Y  Janelle & Sally      BK
# 4                                             Y  Janelle & Sally      BK
#
#       ...      Non-cons 2 Num_All_2  denom_all_2.1  Name* Cons*  Num_Green  \
# 0     ...            4/34       4.0             34    NaN   NaN        NaN
# 1     ...            3/18       3.0             18    NaN   NaN        NaN
# 2     ...           10/42      10.0             42    NaN   NaN        NaN
# 3     ...           11/34      11.0             34    NaN   NaN        NaN
# 4     ...           20/50      20.0             50    NaN   NaN        NaN
#
#    Denom_All Non-cons* Num_All  Denom_All.1
# 0        NaN       NaN     NaN          NaN
# 1        NaN       NaN     NaN          NaN
# 2        NaN       NaN     NaN          NaN
# 3        NaN       NaN     NaN          NaN
# 4        NaN       NaN     NaN          NaN
#
# [5 rows x 31 columns]

# %%
print  mc.dtypes
# Out:
# outletID                     int64
# Subway Station              object
# Tobacco Outlet Address      object
# ZIP                          int64
# Important Notes             object
# Images (Y/N)                object
# Quality (Y/N)               object
# Quality (Y/N) Comments      object
# Name                        object
# Borough                     object
# name_1                      object
# Cons 1                      object
# numerator green_1            int64
# denom_all_1                  int64
# Non-cons 1                  object
# numerator all_1              int64
# denom_all_1.1                int64
# name_2                      object
# Cons 2                      object
# numerator green_2          float64
# denom_all_2                float64
# Non-cons 2                  object
# Num_All_2                  float64
# denom_all_2.1               object
# Name*                       object
# Cons*                       object
# Num_Green                  float64
# Denom_All                  float64
# Non-cons*                   object
# Num_All                    float64
# Denom_All.1                float64
# dtype: object

# %%
#mc= mc.reset_index()
#del mc['index']

# %%
#mc = mc.reset_index(drop=True)

mc.reset_index(inplace=True)

# %%
# making sure .1 and .2 are duplicats 

print mc['denom_all_1.1'].head()
print mc['denom_all_1'].head()
print mc['denom_all_2.1'].head()
print mc['denom_all_2'].head()
print mc['Denom_All.1'].head()
# Out:
# 0     38
# 1     14
# 2    339
# 3     34
# 4     46
# Name: denom_all_1.1, dtype: int64
# 0     38
# 1     14
# 2    339
# 3     34
# 4     46
# Name: denom_all_1, dtype: int64
# 0    34
# 1    18
# 2    42
# 3    34
# 4    50
# Name: denom_all_2.1, dtype: object
# 0    34.0
# 1    18.0
# 2    42.0
# 3    34.0
# 4    50.0
# Name: denom_all_2, dtype: float64
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Denom_All.1, dtype: float64

# %%
# delete duplicates 

del mc['denom_all_1.1']

del mc['denom_all_2.1']

del mc['Denom_All.1']

# %%
#how does it looks now? 

print  mc.dtypes
# Out:
# index                        int64
# outletID                     int64
# Subway Station              object
# Tobacco Outlet Address      object
# ZIP                          int64
# Important Notes             object
# Images (Y/N)                object
# Quality (Y/N)               object
# Quality (Y/N) Comments      object
# Name                        object
# Borough                     object
# name_1                      object
# Cons 1                      object
# numerator green_1            int64
# denom_all_1                  int64
# Non-cons 1                  object
# numerator all_1              int64
# name_2                      object
# Cons 2                      object
# numerator green_2          float64
# denom_all_2                float64
# Non-cons 2                  object
# Num_All_2                  float64
# Name*                       object
# Cons*                       object
# Num_Green                  float64
# Denom_All                  float64
# Non-cons*                   object
# Num_All                    float64
# dtype: object

# %%
# create new columns to caclulate the prcentage of green products in the 
#"power wall" by dviding numerator green by denominator green


#for green 1

mc['precgreen1'] = (mc['numerator green_1']/mc['denom_all_1'])*100

#for green 2

mc['precgreen2'] = (mc['numerator green_2']/mc['denom_all_2'])*100

#for non green menthol products 1

mc['precall1'] = (mc['numerator all_1']/mc['denom_all_1'])*100

#for non green menthol products 2

mc['precall2'] = (mc['Num_All_2']/mc['denom_all_2'])*100

# %%
#mc['Num_All_2']['precall2'][71:74]

# %%
#averge between rater one and rater two. 

# for green apply: create new column for:  (precntage of green 1 + precentage of green 2)/ 2 

mc['avrgreen'] = (mc['precgreen1'] + mc['precgreen2']) / 2


# for green + non green menthol products apply: (precntage of all 1 + precentage of all 2)/ 2 

mc['avrall'] = (mc['precall1'] + mc['precall2']) / 2

# %%
#does the avr look reasonable for green rating? 

#new
print mc['avrgreen'].head()
#and the rest
print mc['precgreen1'].head()
print mc['precgreen2'].head()
# Out:
# 0    10.835913
# 1    19.047619
# 2    15.992415
# 3    26.470588
# 4    30.217391
# Name: avrgreen, dtype: float64
# 0    15.789474
# 1    21.428571
# 2    17.699115
# 3    26.470588
# 4    30.434783
# Name: precgreen1, dtype: float64
# 0     5.882353
# 1    16.666667
# 2    14.285714
# 3    26.470588
# 4    30.000000
# Name: precgreen2, dtype: float64

# %%
# how about for non green products? 

#new
print mc['avrall'].head()

#an the rest
print mc['precall1'].head()
print mc['precall2'].head()

# when there's an NaN in one column or both the avr will be NaN as well
# Out:
# 0    13.777090
# 1    22.619048
# 2    20.754319
# 3    30.882353
# 4    36.304348
# Name: avrall, dtype: float64
# 0    15.789474
# 1    28.571429
# 2    17.699115
# 3    29.411765
# 4    32.608696
# Name: precall1, dtype: float64
# 0    11.764706
# 1    16.666667
# 2    23.809524
# 3    32.352941
# 4    40.000000
# Name: precall2, dtype: float64

# %%
# let's try to identify outliers or gaps among raters. 
# to do so I will calculate the absulute interval b/w the 
# precentage of green products of rater 1 and rater 2 

# create a new column ==  | %green1 - %green2 |

mc['green_gap'] = abs(mc['precgreen1'] - mc['precgreen2'])

# create a new column ==  | %green1 - %green2 | 

mc['all_gap'] = abs(mc['precall1'] - mc['precall2'])


print mc.green_gap.head()

print mc.all_gap.head()
# Out:
# 0    9.907121
# 1    4.761905
# 2    3.413401
# 3    0.000000
# 4    0.434783
# Name: green_gap, dtype: float64
# 0     4.024768
# 1    11.904762
# 2     6.110409
# 3     2.941176
# 4     7.391304
# Name: all_gap, dtype: float64

# %%
#plot the gap b/w rater one and rater 2


mc.green_gap.plot()

mc.all_gap.plot()

print "green mean", mc.green_gap.mean()

print "all mean", mc.all_gap.mean()
# Out:
# green mean 10.6861226067
# all mean 13.1736452007

# %%
# calculate standard deviation 

# 1. for all
print "std of precentage of all", mc.avrall.std()

# 2. for green 

print "std of precentage of green", mc.avrgreen.std()
# Out:
# std of precentage of all 15.9582142678
# std of precentage of green 15.6805317437

# %%
# plot the

# %%
# create data frames which have more than 20% gap b/w raters

mc_green_gap = mc[mc['green_gap']>20]
mc_all_gap = mc[mc['all_gap']>20]

#who is this outlier? 
print mc[mc['green_gap']>50].head()
# Out:
#      index  outletID                        Subway Station  \
# 76      76        77  Westchester Sq - E Tremont, 6 train
# 83      83        84                       125 St, 1 train
# 123    123       124                     67th Ave. (E,M,R)
#
#                     Tobacco Outlet Address    ZIP             Important Notes  \
# 76   134 WESTCHESTER SQUARE Bronx NY 10461  10461                Vendor empty
# 83       501 W 125TH ST Manhattan NY 10027  10027                         NaN
# 123         6725 AUSTIN ST Queens NY 11375  11375  partially blocked by signs
#
#     Images (Y/N) Quality (Y/N) Quality (Y/N) Comments     Name    ...      \
# 76             Y             Y                       Y     NaN    ...
# 83             Y             Y           Y; acceptable   Sally    ...
# 123            Y             Y            Y-acceptable  Rachel    ...
#
#     Non-cons* Num_All precgreen1  precgreen2   precall1   precall2   avrgreen  \
# 76        NaN     NaN   0.000000   66.666667   0.000000  66.666667  33.333333
# 83        NaN     NaN  22.500000   75.000000  22.500000  83.333333  48.750000
# 123       NaN     NaN  66.666667   15.384615  66.666667  21.153846  41.025641
#
#         avrall  green_gap    all_gap
# 76   33.333333  66.666667  66.666667
# 83   52.916667  52.500000  60.833333
# 123  43.910256  51.282051  45.512821
#
# [3 rows x 37 columns]

# %%
mc_green_gap.head()
# Out:
#     index  outletID               Subway Station  \
# 10     10        11          Kings Highway (B,Q)
# 19     19        20           Kosciuszko St. (J)
# 29     29        30  Pennsylvania Ave. (2,3,4,5)
# 30     30        31  Pennsylvania Ave. (2,3,4,5)
# 37     37        38           Sterling St. (2,5)
#
#                     Tobacco Outlet Address    ZIP Important Notes  \
# 10        1521 KINGS HWY Brooklyn NY 11229  11229        Pharmacy
# 19         1165 BROADWAY Brooklyn NY 11221  11221             NaN
# 29       578 LIVONIA AVE Brooklyn NY 11207  11207             NaN
# 30  504 PENNSYLVANIA AVE Brooklyn NY 11207  11207             NaN
# 37     1037 NOSTRAND AVE Brooklyn NY 11225  11225             NaN
#
#    Images (Y/N) Quality (Y/N)               Quality (Y/N) Comments      Name  \
# 10            Y             Y                      Y - Good quality  Janelle
# 19            Y             Y           Y - Not as clear but usable  Janelle
# 29            Y            Y          Y - Good but slightly blurry   Janelle
# 30            Y            Y   Y - Good quality although a bit dark  Janelle
# 37            Y            Y                       Y - Good quality  Janelle
#
#       ...     Non-cons* Num_All precgreen1  precgreen2   precall1   precall2  \
# 10    ...           NaN     NaN  12.307692   45.161290  16.923077  12.903226
# 19    ...           NaN     NaN  17.307692   46.153846  17.307692  46.153846
# 29    ...           NaN     NaN  28.571429   50.000000  28.571429  66.666667
# 30    ...           NaN     NaN  11.111111   42.105263  11.111111  57.894737
# 37    ...           NaN     NaN   7.692308   30.769231   7.692308  30.769231
#
#      avrgreen     avrall  green_gap    all_gap
# 10  28.734491  14.913151  32.853598   4.019851
# 19  31.730769  31.730769  28.846154  28.846154
# 29  39.285714  47.619048  21.428571  38.095238
# 30  26.608187  34.502924  30.994152  46.783626
# 37  19.230769  19.230769  23.076923  23.076923
#
# [5 rows x 37 columns]

# %%
len(mc_all_gap)
# Out:
# 34

# %%
len(mc_green_gap)
# Out:
# 29

# %%
#create data frames for each borough 

# 1. Queens: 

qndf = mc[mc['Borough'] =='QN']

# 2. Brooklyn: 

bkdf = mc[mc['Borough']== 'BK']

# 3. Bronx 

bxdf = mc[mc['Borough']== 'BX']

# 4. Manahttan 

mndf = mc[mc['Borough']== 'MN']

# %%
# print number of outlets per borough

print 'bronx', len(bxdf)

print 'brooklyn', len(bkdf)

print 'queens' , len(qndf)

print 'manahattan', len(mndf)
# Out:
# bronx 39
# brooklyn 39
# queens 46
# manahattan 38

# %%
# reset 4 df index 

mndf.reset_index(inplace=True)
qndf.reset_index(inplace=True)
bxdf.reset_index(inplace=True)
bkdf.reset_index(inplace=True)

# %%
# plot the precentage green and non green for each boroough 

#bronx

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Bronx')

bxdf.avrall.plot()

bxdf.avrgreen.plot()
plt.show()

#brooklyn

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Brooklyn')

bkdf.avrall.plot()

bkdf.avrgreen.plot()
plt.show()

#Manahattan 

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Manahattan')

mndf.avrall.plot()

mndf.avrgreen.plot()
plt.show()


#Queens

fig = plt.figure()
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

ax.set_title('Queens')

qndf.avrall.plot()

qndf.avrgreen.plot()
plt.show()

# %%
del mndf['index']

# %%
bkdf
# Out:
#     level_0  index  outletID               Subway Station  \
# 0         0      0         1               7th Ave. (B,Q)
# 1         1      1         2               7th Ave. (B,Q)
# 2         2      2         3               7th Ave. (B,Q)
# 3         3      3         4             Bedford Ave. (L)
# 4         4      4         5             Bedford Ave. (L)
# 5         5      5         6             Bedford Ave. (L)
# 6         6      6         7             Bedford Ave. (L)
# 27        734 DUMONT AVE Brooklyn NY 11207  11207
# 28     575 RIVERDALE AVE Brooklyn NY 11207  11207
# 29       578 LIVONIA AVE Brooklyn NY 11207  11207
# 30  504 PENNSYLVANIA AVE Brooklyn NY 11207  11207
# 31  509 PENNSYLVANIA AVE Brooklyn NY 11207  11207
# 32      413 LEFFERTS AVE Brooklyn NY 11225  11225
# 33       250 EMPIRE BLVD Brooklyn NY 11225  11225
# 34     1079 NOSTRAND AVE Brooklyn NY 11225  11225
# 35     1080 NOSTRAND AVE Brooklyn NY 11225  11225
# 36     1040 NOSTRAND AVE Brooklyn NY 11225  11225
# 37     1037 NOSTRAND AVE Brooklyn NY 11225  11225
# 38        410 ROGERS AVE Brooklyn NY 11225  11225
#
#                                     Important Notes Images (Y/N)  \
# 0                   partially hidden behind counter            Y
# 1         very far behind counter, difficult to see            Y
# 2                       Difficult to see if menthol           Y
# 3                                               NaN            Y
# 4                                               NaN            Y
# 5                       paritally blocked by vendor            Y
# 6                                               NaN            Y
# 7                             display is misleading            Y
# 8                           Best wall of cigs seen             Y
# 9                                 blocked by vendor            Y
# 10                                         Pharmacy            Y
# 11                                              NaN            Y
# 12                                              NaN            Y
# 13                                              NaN            Y
# 14  Don't have clear photos of full counter display            Y
# 15                                              NaN            Y
# 16                                              NaN            Y
# 17                                              NaN            Y
# 18                                         Pharmacy            Y
# 19                                              NaN            Y
# 20                                              NaN            Y
# 21                                              NaN            Y
# 22                                              NaN            Y
# 23                                      1/3 menthol            Y
# 24                                              NaN            Y
# 25                                              NaN            Y
# 26                                              NaN            Y
# 27                                              NaN            Y
# 28                             Not clearly visible             Y
# 29                                              NaN            Y
# 30                                              NaN            Y
# 31            Folder on drive labeled "Probably(?)"            Y
# 32                                              NaN            Y
# 33                                              NaN            Y
# 34                                        no prices            Y
# 35                                        no prices            Y
# 36                                              NaN            Y
# 37                                              NaN            Y
# 38                   cigs are hidden behind counter            Y
#
#    Quality (Y/N)                            Quality (Y/N) Comments   \
# 0              Y                                                  Y
# 1             Y        Y - But does not capture all cigs on display
# 2             Y                                         Y - Blurry
# 3              Y                                                  Y
# 4              Y                                                  Y
# 5             Y                                       Y-acceptable
# 6             Y                                       Y-acceptable
# 7             Y                                                   Y
# 8             Y                                                  Y
# 9              Y                                                 N
# 10             Y                                   Y - Good quality
# 11             Y                                   Y - Good quality
# 12             Y                                   Y - Good quality
# 13            Y               Y - Not as clear as others but usable
# 14            Y   Y - Some are clear but does not capture all ci...
# 15            Y               Y - Not as clear as others but usable
# 16            Y                                    Y - Good quality
# 17            Y                                    Y - Good quality
# 18            Y                                    Y - Good quality
# 19             Y                        Y - Not as clear but usable
# 20             Y                        Y - Not as clear but usable
# 21            Y   Y - Good quality but cannot really identify nu...
# 22            Y   Y - Good quality but cannot really identify nu...
# 23             Y           Y - Blocked view but was able to analyze
# 24             Y                                                  Y
# 25             Y                                                  Y
# 26             Y                                                  Y
# 27            Y   Y - Blurry but usable; number of packs cannot ...
# 28            Y               Y - Cigs are hidden in clear pictures
# 29            Y                       Y - Good but slightly blurry
#
#                                    Important Notes Images (Y/N) Quality (Y/N)  \
# 12  photos maybe be switched with the outlet below            Y             Y
# 14                                             NaN            Y             Y
# 18                                      bad images            Y             N
# 29                                             NaN            Y             Y
# 30                                             NaN            Y             Y
# 31                                     Duane Reade            Y             Y
# 32                                     Duane Reade            Y             Y
# 33                                             NaN            Y             Y
#
#                 Quality (Y/N) Comments     Name    ...     Non-cons* Num_All  \
# 12                        Y; acceptable   Sally    ...           NaN     NaN
# 14                        Y; acceptable   Sally    ...           NaN     NaN
# 18                                  NaN     NaN    ...           NaN     NaN
# 29  okay, but could use closer pictures   Sally    ...           NaN     NaN
# 30                        yes, perfect!   Sally    ...           NaN     NaN
# 31          yes, but cashier in the way   Sally    ...           NaN     NaN
# 32                   yes, good pictures   Sally    ...           NaN     NaN
# 33                                    Y  Rachel    ...           NaN     NaN
#
#    precgreen1  precgreen2   precall1   precall2   avrgreen     avrall  \
# 12   9.411765   21.739130  12.941176  26.482213  15.575448  19.711695
# 14  13.888889   10.000000  19.444444  13.333333  11.944444  16.388889
# 18  16.666667   16.666667  16.666667  16.666667  16.666667  16.666667
# 29  11.111111   21.481481  13.450292  22.962963  16.296296  18.206628
# 30  18.716578   13.768116  10.160428  18.840580  16.242347  14.500504
# 31  13.125000   14.035088  16.562500  17.894737  13.580044  17.228618
# 32  10.559006    8.992806  16.149068  14.388489   9.775906  15.268779
# 33  10.526316   11.200000  10.526316  20.000000  10.863158  15.263158
#
#     green_gap    all_gap
# 12  12.327366  13.541037
# 14   3.888889   6.111111
# 18   0.000000   0.000000
# 29  10.370370   9.512671
# 30   4.948462   8.680152
# 31   0.910088   1.332237
# 32   1.566200   1.760579
# 33   0.673684   9.473684
#
# [8 rows x 37 columns]

# %%
#calculate average for each borough - data frame for both green and all, one value

# Bronx 

print '- Bronx average all is',  bxdf.avrall.mean()
print '- Bronx average green is',  bxdf.avrgreen.mean()

# Brooklyn 

print '- Brooklyn average all is',  bkdf.avrall.mean()
print '- Brooklyn average green is',  bkdf.avrgreen.mean()

# Queens 

print '- Queens average all is',  qndf.avrall.mean()
print '- Queens average green is',  qndf.avrgreen.mean()

# Manahattan 

print '- Manahattan average all is',  mndf.avrall.mean()
print '- Manahattan average green is',  mndf.avrgreen.mean()
# Out:
# - Bronx average all is 39.0512636931
# - Bronx average green is 34.9688939246
# - Brooklyn average all is 33.6718250267
# - Brooklyn average green is 29.4244644577
# - Queens average all is 37.9173209297
# - Queens average green is 29.6516337811
# - Manahattan average all is 33.3306638771
# - Manahattan average green is 26.4493733592

# %%
#average of green products per

# %%
print mc['precgreen2'].head()
print mc['precall2'].head()
# Out:
# 0     5.882353
# 1    16.666667
# 2    14.285714
# 3    26.470588
# 4    30.000000
# Name: precgreen2, dtype: float64
# 0    11.764706
# 1    16.666667
# 2    23.809524
# 3    32.352941
# 4    40.000000
# Name: precall2, dtype: float64

# %%
#green1 =mc['numeratorgreen1'].tolist()
#green2 =mc['numeratorgreen2'].tolist()

# %% [markdown]
# ## cohen's kappa test:

# %%
#testing cohen's kappa with fabricated lists as inputs
green1 = [2,3,4,5,5,5,5,5,4,3,3,2,2]
green2 = [2,3,4,5,5,5,5,5,4,4,3,2,2]
mc['numeratorgreen1'] = mc['numerator green_1']
mc['numeratorgreen2'] = mc['numerator green_2']

# %%
cohen_kappa_score(precgreen1, precgreen2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-17f136678d6e> in <module>()
# ----> 1 cohen_kappa_score(precgreen1, precgreen2)
#
# NameError: name 'precgreen1' is not defined

# %%
len(mc)

# %%
print mc.columns

# %%
print mc['Borough'].value_counts()

# %%
print mc['Subway Station'].value_counts()

# %%
#print mc['ZIP'].value_counts()

# %% [markdown]
# ### Calculate precentage of green products per rater #1

# %%
#mc['rater_1_green_prec'] = mc['numerator green_1']/ mc['denominator green_1']

# %%
#print mc['rater_1_green_prec'].head(10)

# %% [markdown]
# ### Calculate precentage of all menthol products per rater #1

# %%
 mc['rater_1_all_prec']= mc['numerator all_1']/ mc['denominator all_1']

# %%
print mc['rater_1_all_prec'].head(10)

# %% [markdown]
# ### Calculate precentage of green products per rater #2

# %%
mc['rater_2_green_prec'] = mc['numerator green_2']/ mc['denominator green_2']

# %%
print mc['rater_2_green_prec'].head(10)

# %% [markdown]
# ## DataFrame to CSV

# %%
mc.to_csv('mapcorps analysis')

# %%
 mc[mc['Borough']=='BK' & mc['Images (Y/N)']=='Y', 'yes', 'no')]

# %% [markdown]
# ## by borough have images at all

# %%
print "Brooklyn Images", len(mc[(mc['Borough'] == "BK") & (mc['Images (Y/N)'] == "Y")]) 
print "Queens Imgeas", len(mc[(mc['Borough'] == "QN") & (mc['Images (Y/N)'] == "Y")]) 
print "Bronx Images", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y")]) 
print "Manhattan Images", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y")])

# %% [markdown]
# ## by borough have images with good quality

# %%
#print "Brooklyn", len(mc[(mc['Borough'] == "BK") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 
print "Brooklyn quality", len(mc[(mc['Borough'] == "BK")  & (mc['Images (Y/N)'] == "Y")& (mc['Quality (Y/N)'] == "Y")]) 
print "Queens quality", len(mc[(mc['Borough'] == "QN")  & (mc['Images (Y/N)'] == "Y")& (mc['Quality (Y/N)'] == "Y")]) 
print "Bronx quality", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 
print "Manhattan quality", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y") & (mc['Quality (Y/N)'] == "Y")]) 



#print "Queens", len(mc[(mc['Borough'] == "QN") & (mc['Images (Y/N)'] == "Y")]) 
#print "Bronx", len(mc[(mc['Borough'] == "BX") & (mc['Images (Y/N)'] == "Y")]) 
#print "Manhattan", len(mc[(mc['Borough'] == "MN") & (mc['Images (Y/N)'] == "Y")])

# %%
print mc.columns

# %%
mc.Borough.unique()

# %%
mc['SubwaySatation'] = mc['Subway Station']

# %%
mc.SubwaySatation.unique()

# %%
mc.ZIP.unique()

# %%
mc.Name.unique()
